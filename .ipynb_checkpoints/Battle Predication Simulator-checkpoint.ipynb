# %% [markdown]
# ![batttle screen.png](data:image/png;base64,...)

# %% [markdown]
# # **Welcome to the Ultimate Machine Learning Adventure**
# * This notebook demonstrates the process of predicting battle outcomes of fictional characters using machine learning. The workflow includes data preprocessing, model training, evaluation, and deployment through a web application.
#
# * Dive into this comprehensive notebook and embark on an exciting journey through the entire machine learning lifecycle, from data ingestion to deployment. This notebook is crafted to empower you to run full-scale projects from scratch, offering inspiration and guidance for end-to-end machine learning endeavors.
#
# # Data Handling:
#
# * Using pandas for data manipulation.
# * Visualizing data with matplotlib and seaborn.
#
# # Data Preprocessing:
#
# * Encoding categorical variables with LabelEncoder.
# * plitting the dataset into training and testing sets.
#
# # Model Training and Evaluation:
#
# * Training models using AdaBoostClassifier and RandomForestClassifier from scikit-learn.
# * Evaluating model performance with metrics like accuracy and F1 score.
#
# # Machine Learning Experiment Tracking:
#
# * Logging experiments, metrics, and models using MLflow.
#
# # Model Deployment:
#
# * Saving the trained model and encoders with joblib.
# * Building a web application using Flask to serve predictions based on user inputs.
#
# # Dockerfile:
# * Run your model without installing any environment any python libraries.
# * At the end of noteboook you will find link of dockerhub just copy and past it in your terminal.

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier, RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier, VotingClassifier

# Evaluating Model
from sklearn.metrics import accuracy_score,classification_report,f1_score, precision_recall_fscore_support,precision_recall_curve,precision_score, confusion_matrix

# Machine Learning Experiment 
import mlflow
import mlflow.sklearn

import joblib

# %%
# Setting Up MlFlow:
mlflow.set_experiment('Battle Prediction')
# Out:
# <Experiment: artifact_location='file:///C:/Users/Moin/Science%20learning/Kaggle/Kaggle.notebookv2/mlruns/861731853904937241', creation_time=1722919683514, experiment_id='861731853904937241', last_update_time=1722919683514, lifecycle_stage='active', name='Battle Prediction', tags={}>

# %%
# Define a function to style the DataFrame for better readability
def style_dataframe(df):
    """
    Applies a consistent styling to the DataFrame.

    Parameters:
        df (pd.DataFrame): The DataFrame to style.

    Returns:
        pd.io.formats.style.Styler: The styled DataFrame.
    """
    # Use a color palette for header and even/odd rows
    palette = sns.color_palette("coolwarm", n_colors=63)

    return df.style.set_table_styles(
        [
            {
                'selector': 'thead th',
                'props': [
                    ('background-color', palette[0]),  # First color from palette for header
                    ('color', '#FFFFFF'),  # White text for header
                    ('font-weight', 'bold'),
                    ('text-align', 'center'),
                    ('border', f'1px solid {palette[0]}'),  # Same color as header background for border
                ]
            },
            {
                'selector': 'tbody td',
                'props': [
                    ('background-color', '#FFFFFF'),  # White background for cells
                    ('border', '1px solid #DDDDDD'),  # Light grey border for cells
                    ('color', '#333333'),  # Dark grey text for better readability
                ]
            },
            {
                'selector': 'tbody tr:nth-child(even) td',
                'props': [
                    ('background-color', palette[1])  # Second color from palette for even rows
                ]
            },
            {
                'selector': 'tbody tr:nth-child(odd) td',
                'props': [
                    ('background-color', palette[2])  # Third color from palette for odd rows
                ]
            }
        ]
    ).set_properties(**{'text-align': 'center'}).set_table_attributes('style="width:100%;"').hide(axis='index')

# %% [markdown]
# ## Script Overview
# This script processes a dataset containing fictional character battle attributes. It includes data loading, basic analysis, visualization, and correlation analysis. The script also features a custom DataFrame styling function for better readability when displaying data.

# %%
# Read the data from a CSV file (replace 'your_data.csv' with your actual file path)
df = pd.read_csv(r"C:\Users\Moin\Science learning\Data_Projects\Machine Learning\Self_learning\csv\fictional_character_battles.csv")

# Optionally, display the rows using head()
style = style_dataframe(df.head(11))
display(style)  # Use display to render the styled DataFrame
# Out:
# <style type="text/css">
# #T_ec7b7 thead th {
#   background-color: (0.24809121780392157, 0.3260130233176471, 0.7776686513529412);
#   color: #FFFFFF;
#   font-weight: bold;
#   text-align: center;
#   border: 1px solid (0.24809121780392157, 0.3260130233176471, 0.7776686513529412);
# }
# #T_ec7b7 tbody td {
#   background-color: #FFFFFF;
#   border: 1px solid #DDDDDD;
#   color: #333333;
# }
# #T_ec7b7 tbody tr:nth-child(even) td {
#   background-color: (0.26638146835294113, 0.35330440842352945, 0.8016373194980392);
# }
# #T_ec7b7 tbody tr:nth-child(odd) td {
#   background-color: (0.28527277752941177, 0.38012942263529415, 0.8234685512470589);
# }
# #T_ec7b7_row0_col0, #T_ec7b7_row0_col1, #T_ec7b7_row0_col2, #T_ec7b7_row0_col3, #T_ec7b7_row0_col4, #T_ec7b7_row0_col5, #T_ec7b7_row0_col6, #T_ec7b7_row0_col7, #T_ec7b7_row1_col0, #T_ec7b7_row1_col1, #T_ec7b7_row1_col2, #T_ec7b7_row1_col3, #T_ec7b7_row1_col4, #T_ec7b7_row1_col5, #T_ec7b7_row1_col6, #T_ec7b7_row1_col7, #T_ec7b7_row2_col0, #T_ec7b7_row2_col1, #T_ec7b7_row2_col2, #T_ec7b7_row2_col3, #T_ec7b7_row2_col4, #T_ec7b7_row2_col5, #T_ec7b7_row2_col6, #T_ec7b7_row2_col7, #T_ec7b7_row3_col0, #T_ec7b7_row3_col1, #T_ec7b7_row3_col2, #T_ec7b7_row3_col3, #T_ec7b7_row3_col4, #T_ec7b7_row3_col5, #T_ec7b7_row3_col6, #T_ec7b7_row3_col7, #T_ec7b7_row4_col0, #T_ec7b7_row4_col1, #T_ec7b7_row4_col2, #T_ec7b7_row4_col3, #T_ec7b7_row4_col4, #T_ec7b7_row4_col5, #T_ec7b7_row4_col6, #T_ec7b7_row4_col7, #T_ec7b7_row5_col0, #T_ec7b7_row5_col1, #T_ec7b7_row5_col2, #T_ec7b7_row5_col3, #T_ec7b7_row5_col4, #T_ec7b7_row5_col5, #T_ec7b7_row5_col6, #T_ec7b7_row5_col7, #T_ec7b7_row6_col0, #T_ec7b7_row6_col1, #T_ec7b7_row6_col2, #T_ec7b7_row6_col3, #T_ec7b7_row6_col4, #T_ec7b7_row6_col5, #T_ec7b7_row6_col6, #T_ec7b7_row6_col7, #T_ec7b7_row7_col0, #T_ec7b7_row7_col1, #T_ec7b7_row7_col2, #T_ec7b7_row7_col3, #T_ec7b7_row7_col4, #T_ec7b7_row7_col5, #T_ec7b7_row7_col6, #T_ec7b7_row7_col7, #T_ec7b7_row8_col0, #T_ec7b7_row8_col1, #T_ec7b7_row8_col2, #T_ec7b7_row8_col3, #T_ec7b7_row8_col4, #T_ec7b7_row8_col5, #T_ec7b7_row8_col6, #T_ec7b7_row8_col7, #T_ec7b7_row9_col0, #T_ec7b7_row9_col1, #T_ec7b7_row9_col2, #T_ec7b7_row9_col3, #T_ec7b7_row9_col4, #T_ec7b7_row9_col5, #T_ec7b7_row9_col6, #T_ec7b7_row9_col7, #T_ec7b7_row10_col0, #T_ec7b7_row10_col1, #T_ec7b7_row10_col2, #T_ec7b7_row10_col3, #T_ec7b7_row10_col4, #T_ec7b7_row10_col5, #T_ec7b7_row10_col6, #T_ec7b7_row10_col7 {
#   text-align: center;
# }
# </style>
# <table id="T_ec7b7" style="width:100%;">
#   <thead>
#     <tr>
#       <th id="T_ec7b7_level0_col0" class="col_heading level0 col0" >Character</th>
#       <th id="T_ec7b7_level0_col1" class="col_heading level0 col1" >Universe</th>
#       <th id="T_ec7b7_level0_col2" class="col_heading level0 col2" >Strength</th>
#       <th id="T_ec7b7_level0_col3" class="col_heading level0 col3" >Speed</th>
#       <th id="T_ec7b7_level0_col4" class="col_heading level0 col4" >Intelligence</th>
#       <th id="T_ec7b7_level0_col5" class="col_heading level0 col5" >SpecialAbilities</th>
#       <th id="T_ec7b7_level0_col6" class="col_heading level0 col6" >Weaknesses</th>
#       <th id="T_ec7b7_level0_col7" class="col_heading level0 col7" >BattleOutcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ec7b7_row0_col0" class="data row0 col0" >Wonder Woman</td>
#       <td id="T_ec7b7_row0_col1" class="data row0 col1" >Marvel</td>
#       <td id="T_ec7b7_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_ec7b7_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_ec7b7_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_ec7b7_row0_col5" class="data row0 col5" >Telekinesis</td>
#       <td id="T_ec7b7_row0_col6" class="data row0 col6" >Kryptonite</td>
#       <td id="T_ec7b7_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row1_col0" class="data row1 col0" >Iron Man</td>
#       <td id="T_ec7b7_row1_col1" class="data row1 col1" >Marvel</td>
#       <td id="T_ec7b7_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_ec7b7_row1_col3" class="data row1 col3" >7</td>
#       <td id="T_ec7b7_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_ec7b7_row1_col5" class="data row1 col5" >Telekinesis</td>
#       <td id="T_ec7b7_row1_col6" class="data row1 col6" >Kryptonite</td>
#       <td id="T_ec7b7_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row2_col0" class="data row2 col0" >Iron Man</td>
#       <td id="T_ec7b7_row2_col1" class="data row2 col1" >DC Comics</td>
#       <td id="T_ec7b7_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_ec7b7_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_ec7b7_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_ec7b7_row2_col5" class="data row2 col5" >Telekinesis</td>
#       <td id="T_ec7b7_row2_col6" class="data row2 col6" >Magic</td>
#       <td id="T_ec7b7_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row3_col0" class="data row3 col0" >Spider-Man</td>
#       <td id="T_ec7b7_row3_col1" class="data row3 col1" >DC Comics</td>
#       <td id="T_ec7b7_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_ec7b7_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_ec7b7_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_ec7b7_row3_col5" class="data row3 col5" >Telekinesis</td>
#       <td id="T_ec7b7_row3_col6" class="data row3 col6" >Kryptonite</td>
#       <td id="T_ec7b7_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row4_col0" class="data row4 col0" >Flash</td>
#       <td id="T_ec7b7_row4_col1" class="data row4 col1" >Marvel</td>
#       <td id="T_ec7b7_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_ec7b7_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_ec7b7_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_ec7b7_row4_col5" class="data row4 col5" >Invisibility</td>
#       <td id="T_ec7b7_row4_col6" class="data row4 col6" >Magic</td>
#       <td id="T_ec7b7_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row5_col0" class="data row5 col0" >Spider-Man</td>
#       <td id="T_ec7b7_row5_col1" class="data row5 col1" >DC Comics</td>
#       <td id="T_ec7b7_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_ec7b7_row5_col3" class="data row5 col3" >9</td>
#       <td id="T_ec7b7_row5_col4" class="data row5 col4" >7</td>
#       <td id="T_ec7b7_row5_col5" class="data row5 col5" >Invisibility</td>
#       <td id="T_ec7b7_row5_col6" class="data row5 col6" >Wooden Stake</td>
#       <td id="T_ec7b7_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row6_col0" class="data row6 col0" >Wonder Woman</td>
#       <td id="T_ec7b7_row6_col1" class="data row6 col1" >Marvel</td>
#       <td id="T_ec7b7_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_ec7b7_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_ec7b7_row6_col4" class="data row6 col4" >2</td>
#       <td id="T_ec7b7_row6_col5" class="data row6 col5" >Super Strength</td>
#       <td id="T_ec7b7_row6_col6" class="data row6 col6" >Silver</td>
#       <td id="T_ec7b7_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row7_col0" class="data row7 col0" >Thor</td>
#       <td id="T_ec7b7_row7_col1" class="data row7 col1" >DC Comics</td>
#       <td id="T_ec7b7_row7_col2" class="data row7 col2" >7</td>
#       <td id="T_ec7b7_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_ec7b7_row7_col4" class="data row7 col4" >4</td>
#       <td id="T_ec7b7_row7_col5" class="data row7 col5" >Invisibility</td>
#       <td id="T_ec7b7_row7_col6" class="data row7 col6" >Magic</td>
#       <td id="T_ec7b7_row7_col7" class="data row7 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ec7b7_row8_col0" class="data row8 col0" >Batman</td>
#       <td id="T_ec7b7_row8_col1" class="data row8 col1" >DC Comics</td>
#       <td id="T_ec7b7_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_ec7b7_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_ec7b7_row8_col4"

# %% [markdown]
# # Data Loading and Basic Information
# The script reads data from a CSV file into a pandas DataFrame and displays basic information, including shape, summary statistics, and column names. It also checks for missing values.

# %%
df.describe() # Print summary statistics of the DataFrame
# Out:
#           Strength        Speed  Intelligence  BattleOutcome
# count  7943.000000  7943.000000   7943.000000    7943.000000
# mean      5.484829     5.496034      5.502707       0.269168
# std       2.891210     2.868687      2.908789       0.443555
# min       1.000000     1.000000      1.000000       0.000000
# 25%       3.000000     3.000000      3.000000       0.000000
# 50%       5.000000     6.000000      6.000000       0.000000
# 75%       8.000000     8.000000      8.000000       1.000000
# max      10.000000    10.000000     10.000000       1.000000

# %%
df.shape # Print the shape of the DataFrame
# Out:
# (7943, 8)

# %%
df.info() # Print information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7943 entries, 0 to 7942
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Character         7943 non-null   object
#  1   Universe          7943 non-null   object
#  2   Strength          7943 non-null   int64
#  3   Speed             7943 non-null   int64
#  4   Intelligence      7943 non-null   int64
#  5   SpecialAbilities  7943 non-null   object
#  6   Weaknesses        7943 non-null   object
#  7   BattleOutcome     7943 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 496.6+ KB

# %%
df.isnull().sum() # Print the number of missing values in each column|
# Out:
# Character           0
# Universe            0
# Strength            0
# Speed               0
# Intelligence        0
# SpecialAbilities    0
# Weaknesses          0
# BattleOutcome       0
# dtype: int64

# %%
df.columns # Print the column names
# Out:
# Index(['Character', 'Universe', 'Strength', 'Speed', 'Intelligence',
#        'SpecialAbilities', 'Weaknesses', 'BattleOutcome'],
#       dtype='object')

# %% [markdown]
# # Unique Values Analysis
# This section extracts and prints unique values from key columns in the dataset. It helps understand the diversity of attributes such as Strength, Weaknesses, Intelligence, Special Abilities, and Character names.

# %%
# Unique values in different columns
Strenghth_val = df.Strength.unique()
Weaknesses_val = df.Weaknesses.unique()
Intelligence_val = df.Intelligence.unique()
SpecialAbilities_val = df.SpecialAbilities.unique()
Character_val = df.Character.nunique()
Character_valu = df.Character.unique()

# Print unique values
print(f'Unique Strength In Heros is:', Strenghth_val)
print(f'Unique Weaknesses In Heros is:', Weaknesses_val)
print(f'Unique Intelligence In Heros is:', Intelligence_val)
print(f'Unique SpecialAbilities In Heros is:', SpecialAbilities_val)
print(f'Number Of Unique Heros Names:', Character_val)
print(f'Names Of The Super Heros:', Character_valu)
# Out:
# Unique Strength In Heros is: [ 7  4  8  5 10  3  6  2  1  9]
# Unique Weaknesses In Heros is: ['Kryptonite' 'Magic' 'Wooden Stake' 'Silver']
# Unique Intelligence In Heros is: [ 3  9  5 10  2  7  4  1  6  8]
# Unique SpecialAbilities In Heros is: ['Telekinesis' 'Invisibility' 'Super Strength' 'Flight']
# Number Of Unique Heros Names: 8
# Names Of The Super Heros: ['Wonder Woman' 'Iron Man' 'Spider-Man' 'Flash' 'Thor' 'Batman' 'Superman'
#  'Captain America']

# %%
# Check specific columns
col_check = df[['Character', 'BattleOutcome']]
col_check.tail(20)  #last 20 rows
# Out:
#          Character  BattleOutcome
# 7923      Superman              0
# 7924          Thor              0
# 7925          Thor              1
# 7926  Wonder Woman              0
# 7927      Superman              1
# 7928      Superman              0
# 7929      Superman              0
# 7930      Iron Man              0
# 7931      Superman              0
# 7932    Spider-Man              0
# 7933      Superman              0
# 7934    Spider-Man              1
# 7935      Iron Man              0
# 7936          Thor              1
# 7937         Flash              0
# 7938    Spider-Man              0
# 7939      Iron Man              0
# 7940         Flash              0
# 7941         Flash              1
# 7942      Superman              0

# %% [markdown]
# # Correlation Analysis
# The script calculates and prints the correlation between attributes like Strength, Speed, Intelligence, and BattleOutcome. This helps identify relationships between different variables.

# %%
col_check = df[['Strength','BattleOutcome']]
col_check.iloc[1560:1600,:] # rows from index 1560 to 1600
# Out:
#       Strength  BattleOutcome
# 1560         5              0
# 1561         8              1
# 1562         5              0
# 1563         8              0
# 1564        10              0
# 1565         1              0
# 1566        10              1
# 1567         9              1
# 1568         6              1
# 1569         3              0
# 1570         8              0
# 1571         9              0
# 1572         6              1
# 1573         7              0
# 1574         1              1
# 1575         5              0
# 1576         5              0
# 1577        10              1
# 1578         4              0
# 1579         6              0
# 1580         7              1
# 1581         9              0
# 1582         1              0
# 1583         6              1
# 1584         7              0
# 1585         3              0
# 1586         8              0
# 1587         5              1
# 1588         9              1
# 1589         5              0
# 1590         9              1
# 1591        10              0
# 1592         4              0
# 1593         9              1
# 1594         5              1
# 1595        10              0
# 1596         9              1
# 1597         3              1
# 1598         4              0
# 1599         9              1

# %%
corr_col = df['Strength'].corr(df['BattleOutcome'])
print(f"Correlation between 'Speed' and 'BattleOutcome': {corr_col:.4f}")
# Out:
# Correlation between 'Speed' and 'BattleOutcome': 0.3073

# %%
col_check = df[['Speed','BattleOutcome']]
col_check.iloc[2260:2300,:]
# Out:
#       Speed  BattleOutcome
# 2260      6              0
# 2261      8              0
# 2262      6              0
# 2263      9              0
# 2264      9              0
# 2265      2              1
# 2266     10              0
# 2267      1              0
# 2268      2              1
# 2269      5              0
# 2270      4              0
# 2271      4              0
# 2272      9              0
# 2273      8              0
# 2274      6              0
# 2275      1              0
# 2276      2              0
# 2277      6              0
# 2278      2              0
# 2279     10              0
# 2280      5              0
# 2281      5              0
# 2282      6              0
# 2283      6              1
# 2284      6              0
# 2285      2              0
# 2286     10              1
# 2287      3              0
# 2288      6              0
# 2289      8              0
# 2290      1              0
# 2291      1              0
# 2292      2              0
# 2293      6              0
# 2294      9              1
# 2295      4              0
# 2296      3              0
# 2297      8              0
# 2298     10              1
# 2299      9              0

# %%
corr_col2 = df['Speed'].corr(df['BattleOutcome'])
print(f"Correlation between 'Speed' and 'BattleOutcome': {corr_col2:.4f}")
# Out:
# Correlation between 'Speed' and 'BattleOutcome': 0.1790

# %%
col_check = df[['Intelligence','BattleOutcome']]
col_check.iloc[3000:3050,:]
# Out:
#       Intelligence  BattleOutcome
# 3000             5              0
# 3001             1              0
# 3002             2              0
# 3003             5              0
# 3004             3              0
# 3005             2              0
# 3006             4              0
# 3007             4              0
# 3008             4              1
# 3009             4              0
# 3010             3              0
# 3011             7              0
# 3012             9              1
# 3013             5              0
# 3014             4              0
# 3015             2              0
# 3016             2              0
# 3017             5              0
# 3018             7              0
# 3019            10              0
# 3020            10              1
# 3021             9              1
# 3022             7              0
# 3023             5              0
# 3024            10              0
# 3025            10              1
# 3026            10              0
# 3027             6              1
# 3028             3              0
# 3029             5              0
# 3030             8              0
# 3031             1              1
# 3032             1              0
# 3033             7              1
# 3034             5              1
# 3035             5              0
# 3036             1              0
# 3037             9              0
# 3038             1              0
# 3039             5              1
# 3040            10              1
# 3041             9              1
# 3042             4              0
# 3043             8              0
# 3044             6              1
# 3045             3              0
# 3046             4              0
# 3047             2              0
# 3048             1              0
# 3049             8              1

# %%
corr_col3 = df['Intelligence'].corr(df['BattleOutcome'])
print(f"Correlation between 'Speed' and 'BattleOutcome': {corr_col3:.4f}")
# Out:
# Correlation between 'Speed' and 'BattleOutcome': 0.2397

# %%
# Separate numeric and character columns
numeric_cols = df.select_dtypes(include = ['int64', 'float64'])
charcter_columns = df.select_dtypes(include=['object'])

# %%
#numeric columns
print(numeric_cols)
# Out:
#       Strength  Speed  Intelligence  BattleOutcome
# 0            7      8             3              0
# 1            4      7             9              0
# 2            8      7             5              0
# 3            5      6            10              0
# 4            7      6             2              0
# ...        ...    ...           ...            ...
# 7938         4      9             7              0
# 7939         9     10             4              0
# 7940         2      5             2              0
# 7941        10      7             5              1
# 7942         9      2             3              0
#
# [7943 rows x 4 columns]

# %%
# character columns
print(charcter_columns)
# Out:
#          Character   Universe SpecialAbilities    Weaknesses
# 0     Wonder Woman     Marvel      Telekinesis    Kryptonite
# 1         Iron Man     Marvel      Telekinesis    Kryptonite
# 2         Iron Man  DC Comics      Telekinesis         Magic
# 3       Spider-Man  DC Comics      Telekinesis    Kryptonite
# 4            Flash     Marvel     Invisibility         Magic
# ...            ...        ...              ...           ...
# 7938    Spider-Man  DC Comics           Flight    Kryptonite
# 7939      Iron Man     Marvel           Flight  Wooden Stake
# 7940         Flash     Marvel           Flight    Kryptonite
# 7941         Flash  DC Comics   Super Strength         Magic
# 7942      Superman  DC Comics   Super Strength  Wooden Stake
#
# [7943 rows x 4 columns]

# %% [markdown]
# # Histograms for numeric columns to show their distribution.
# Boxplots to visualize the relationship between Strength and other attributes.
# A pairplot to visualize relationships between multiple attributes colored by BattleOutcome.

# %%
# Histograms for numeric columns
df.hist(bins = 20, figsize=(10,5),color=['Teal'])
plt.show()

# %%
df.columns
# Out:
# Index(['Character', 'Universe', 'Strength', 'Speed', 'Intelligence',
#        'SpecialAbilities', 'Weaknesses', 'BattleOutcome'],
#       dtype='object')

# %%
# Histogram for specific columns
plt.figure(figsize=(15, 4))
plt.hist([df['Character'], df['Speed']], bins=20, alpha=0.7, color=['Teal', 'PaleVioletRed'], label=['Heros', 'Speed'])
plt.xlabel('Hero Name')
plt.ylabel('Speed Of Heros')
plt.title('Distribution of Hero and Speed')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 4))
plt.hist([df['SpecialAbilities'], df['Intelligence']], bins=20, alpha=0.7, color=['Teal', 'PaleVioletRed'], label=['SpecialAbilities', 'Intelligence'])
plt.xlabel('SpecialAbilities Of Heros')
plt.ylabel('Intelligence Of Heros')
plt.title('Distribution of SpecialAbilities and Intelligence')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 4))
plt.hist([df['Weaknesses'], df['Strength']], bins=20, alpha=0.7, color=['Teal', 'PaleVioletRed'], label=['Weaknesses', 'Strength'])
plt.xlabel('Weaknesses Of Heros')
plt.ylabel('Frequency')
plt.title('Distribution of Weaknesses and Strength')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# # Data Visualization
# The script includes various plots:

# %%
font_color = "Teal"  # You can change this to your preference

plt.figure(figsize=(8, 4))
sns.boxplot(
    data=df,
    x="Strength",
    y="Weaknesses",
    palette="husl",  
    showmeans=True,  # Display means as markers on the boxes
    notch=True,  # Add notches to the boxes for better variability representation
)
# Set font color for various elements
plt.xlabel("Strength", color=font_color)  # X-axis label
plt.ylabel("Weaknesses", color=font_color)  # Y-axis label
plt.title("Boxplot of Strength vs Weaknesses", color=font_color)  # Title
plt.tick_params(colors=font_color)  # Tick labels 
plt.show()

# %%
df.columns
# Out:
# Index(['Character', 'Universe', 'Strength', 'Speed', 'Intelligence',
#        'SpecialAbilities', 'Weaknesses', 'BattleOutcome'],
#       dtype='object')

# %%
font_color = "Teal"  # You can change this to your preference

plt.figure(figsize=(8, 4))
sns.boxplot(
    data=df,
    x="Strength",
    y="Character",
    palette="husl",  
    showmeans=True,  # Display means as markers on the boxes
    notch=True,  # Add notches to the boxes for better variability representation
)
# Set font color for various elements
plt.xlabel("Strength", color=font_color)  # X-axis label
plt.ylabel("Character", color=font_color)  # Y-axis label
plt.title("Boxplot of Strength Of Character", color=font_color)  # Title
plt.tick_params(colors=font_color)  # Tick labels (both axes)

plt.show()

# %%
# Pairplot for the dataset
plt.figure(figsize=(10, 8))
sns.pairplot(data=df, hue='BattleOutcome', palette="husl", diag_kind="kde")
plt.show()

# %%
df.columns
# Out:
# Index(['Character', 'Universe', 'Strength', 'Speed', 'Intelligence',
#        'SpecialAbilities', 'Weaknesses', 'BattleOutcome'],
#       dtype='object')

# %%
charcter_columns
# Out:
#          Character   Universe SpecialAbilities    Weaknesses
# 0     Wonder Woman     Marvel      Telekinesis    Kryptonite
# 1         Iron Man     Marvel      Telekinesis    Kryptonite
# 2         Iron Man  DC Comics      Telekinesis         Magic
# 3       Spider-Man  DC Comics      Telekinesis    Kryptonite
# 4            Flash     Marvel     Invisibility         Magic
# ...            ...        ...              ...           ...
# 7938    Spider-Man  DC Comics           Flight    Kryptonite
# 7939      Iron Man     Marvel           Flight  Wooden Stake
# 7940         Flash     Marvel           Flight    Kryptonite
# 7941         Flash  DC Comics   Super Strength         Magic
# 7942      Superman  DC Comics   Super Strength  Wooden Stake
#
# [7943 rows x 4 columns]

# %%
# Label Encoding
char_label = LabelEncoder()
universe_label = LabelEncoder()
specialAbilities_label = LabelEncoder()
weakness_label = LabelEncoder()

# %%
df['Character'] = char_label.fit_transform(df['Character'])
df['Universe'] = universe_label.fit_transform(df['Universe'])
df['SpecialAbilities'] = specialAbilities_label.fit_transform(df['SpecialAbilities'])
df['Weaknesses'] = weakness_label.fit_transform(df['Weaknesses'])

# %%
df.head(5)
# Out:
#    Character  Universe  Strength  Speed  Intelligence  SpecialAbilities  \
# 0          7         1         7      8             3                 3
# 1          3         1         4      7             9                 3
# 2          3         0         8      7             5                 3
# 3          4         0         5      6            10                 3
# 4          2         1         7      6             2                 1
#
#    Weaknesses  BattleOutcome
# 0           0              0
# 1           0              0
# 2           1              0
# 3           0              0
# 4           1              0

# %%
df.Character.unique()
# Out:
# array([7, 3, 4, 2, 6, 0, 5, 1])

# %%
# Split Data (Independent and Depended)
X_input_data = df.iloc[:,:-1]
y_output_data = df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X_input_data, y_output_data, test_size=0.2, random_state=42)

# %%
Ada_model = AdaBoostClassifier()
Ada_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
Ada_model.score(X_train, y_train)*100, Ada_model.score(X_test, y_test)*100
# Out:
# (80.87818696883853, 80.36500943989931)

# %%
with mlflow.start_run():
    forest_model = RandomForestClassifier(n_estimators=600,
    criterion='entropy',
    max_features='log2',
    n_jobs=1,
    random_state=1,
    verbose=0,
    max_depth=456,
    min_samples_split=2,
    min_samples_leaf=1,
    warm_start=True,)
    forest_model.fit(X_train, y_train)

# %%
forest_model.score(X_train, y_train)*100, forest_model.score(X_test, y_test)*100
# Out:
# (99.88983317595216, 97.23096286972938)

# %% [markdown]
# # Evaulating Model

# %%
y_pred = forest_model.predict(X_test)

F1_Score = f1_score(y_pred, y_test)
Accuracy_Score = accuracy_score(y_pred, y_test)
Report = classification_report(y_pred, y_test)
Confusion_Matrix = confusion_matrix(y_pred, y_test)

print(f'F1 Score:',F1_Score)
print(f'Accuracy Score:',Accuracy_Score)
print(Report,f'Classification Report:')
print(Confusion_Matrix)
# Out:
# F1 Score: 0.948356807511737
# Accuracy Score: 0.9723096286972939
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1168
#            1       0.94      0.96      0.95       421
#
#     accuracy                           0.97      1589
#    macro avg       0.96      0.97      0.96      1589
# weighted avg       0.97      0.97      0.97      1589
#  Classification Report:
# [[1141   27]
#  [  17  404]]

# %%
precision = report['weighted avg']['precision']
recall = report['weighted avg']['recall']

# %%
colour = ['PaleVioletRed','Teal','Pink']
report = classification_report(y_test, y_pred, output_dict=True)

df_report = pd.DataFrame(report).transpose()
# Plot metrics
df_report[['precision', 'recall', 'f1-score']].plot(kind='bar',  color = colour)
plt.title('Classification Report')
plt.ylabel('Metric Value')
plt.xlabel('Class')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# # Creating MLflow Experiment!

# %%
mlflow.log_metric("F1 Score",F1_Score)
mlflow.log_metric("Accuracy Score",Accuracy_Score)
mlflow.log_metric("Precsion Score", precision)
mlflow.log_metric("Recall Score", recall)

Matrix = (Confusion_Matrix.sum(axis=0)[-1] / Confusion_Matrix.sum()) * 100 
mlflow.log_metric("Confusion Matrix", Matrix)

# %%
mlflow.set_tag('Algorithm','RandomForestClassifier')
mlflow.set_tag('Data Size', len(df))
mlflow.set_tag('Model Type', 'Classification')
mlflow.set_tag("Random State",42)
mlflow.set_tag('Test Size', '0.2')

mlflow.sklearn.log_model(forest_model, 'RandomForestClassifier')
# Out:
# 2024/08/06 14:17:31 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.

# %%
mlflow.log_param('criterian',600)
mlflow.log_param('Max_features','log2')
mlflow.log_param('n_jobs',1)
mlflow.log_param('random_state',1)
mlflow.log_param('verbose',0)
mlflow.log_param('max_depth',456)
mlflow.log_param('min_simples_split',2)
mlflow.log_param('min_samples_leaf',1)
mlflow.log_param('warm_start',True)
# Out:
# True

# %%
mlflow.end_run(status="FINISHED")

# %% [markdown]
# # Exporthing required Models in joblib file...

# %%
joblib.dump(char_label,'character_encode')
joblib.dump(universe_label,'universe_encode')
joblib.dump(specialAbilities_label,'Abilities_encode')
joblib.dump(weakness_label,'weaknes_encode')

joblib.dump(forest_model, 'model.joblib')
# Out:
# ['model.joblib']

# %% [markdown]
# ## This is Basic End to End Machine Learning Model I Created To Understand Easily
#
# The notebook provides a comprehensive example of a machine learning pipeline, from data exploration to deployment, enabling users to understand and replicate the process for similar tasks.
#
# # Pull Image from dockerhub:
# **docker pull orhfusion/battle_prediction_simulator**
#
# {run without installing any dependencies & no need to create environment for it...}
#
# # Or you can refer to my GitHub repository to get files:
# https://github.com/OrhFusion/Battle-Predication-Simulator-Model.git
#
#
# * Flask
# * Html
# * Dockerfile
# * app.py
# * Details
# * Dependencies (requirements.txt)
#
# Exposed: Port = 5000.
